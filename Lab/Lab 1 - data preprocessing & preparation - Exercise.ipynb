# %%
# import library used for data management
import numpy as np 
import pandas as pd

# %%
# load datasets
train = pd.read_csv('train.csv',index_col = 'PassengerId')
test = pd.read_csv('test.csv',index_col = 'PassengerId')

# %%
# to view the whole training set
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
# to view the first 5 lines in the training set
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# to view training set information
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
# to descirbe the numerical variables in training set
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# to describe categorical variables in traning set
train['Pclass'].describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %%
train['Sex'].describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %% [markdown]
# ###### view the testing set information, which attributes have missing values?

# %% [markdown]
# # Deal with missing values
# ### The train dataset has missing values in Age, Embarked and Cabin

# %%
# replace missing value in "Age" with mean
train['Age'].fillna(train['Age'].mean(),inplace=True)

# %%
train['Age'].mean()
# Out:
# 29.699117647058763

# %%
# show description of age again
train['Age'].describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# replace missing values in "Embarked" with most frequent appeared value
train['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
train['Embarked'].fillna(train['Embarked'].mode(),inplace=True)

# %%
# directly replace with "S"
#train['Embarked'].fillna("S",inplace=True)
train['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
train['Embarked'].mode()
# Out:
# 0    S
# dtype: object

# %%
train['Embarked'].fillna("S",inplace=True)

# %%
train['Embarked'].describe()
# Out:
# count     891
# unique      3
# top         S
# freq      646
# Name: Embarked, dtype: object

# %%
train['Cabin'].describe()
# Out:
# count     204
# unique    147
# top        G6
# freq        4
# Name: Cabin, dtype: object

# %%
# What shall we do with missing values in "Cabin"? 
# Delete the whole column
train = train.drop(columns='Cabin')

# %%
# Check the training set info again
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 76.6+ KB

# %% [markdown]
# ###### How can you deal with the missing values in test set?

# %% [markdown]
# # Furthur prepare the data

# %% [markdown]
# #### 1. Discretization / Binning

# %%
# Bining / Descritization
# give names for different age group
group_names = ['Young', 'Middle-aged', 'Senior']

# %%
# divide Age into 3 equal interval groups and give corresponding names
train['Age-binned']=pd.cut(train['Age'], 3 , labels=group_names)

# %%
# View Age-binned in bar chart
train['Age-binned'].value_counts().plot(kind='bar')

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#                    Age  SibSp  Parch            Ticket     Fare Embarked  \
# PassengerId
# 1            22.000000      1      0         A/5 21171   7.2500        S
# 2            38.000000      1      0          PC 17599  71.2833        C
# 3            26.000000      0      0  STON/O2. 3101282   7.9250        S
# 4            35.000000      1      0            113803  53.1000        S
# 5            35.000000      0      0            373450   8.0500        S
# ...                ...    ...    ...               ...      ...      ...
# 887          27.000000      0      0            211536  13.0000        S
# 888          19.000000      0      0            112053  30.0000        S
# 889          29.699118      1      2        W./C. 6607  23.4500        S
# 890          26.000000      0      0            111369  30.0000        C
# 891          32.000000      0      0            370376   7.7500        Q
#
#               Age-binned
# PassengerId
# 1                  Young
# 2            Middle-aged
# 3                  Young
# 4            Middle-aged
# 5            Middle-aged
# ...                  ...
# 887          Middle-aged
# 888                Young
# 889          Middle-aged
# 890                Young
# 891          Middle-aged
#
# [891 rows x 11 columns]

# %% [markdown]
# #### 2. Normalization

# %%
# import library 
from sklearn import preprocessing

# %%
# create a scaler using Z score normalization / Standardization on a single attribute
zscore_scaler = preprocessing.StandardScaler().fit(train[['Fare']])

# %%
#Apply the Zscore scaler on a single attribute
train['Fare_zscore']=zscore_scaler.transform(train[['Fare']])

# %%
train['Fare_zscore'].describe()
# Out:
# count    8.910000e+02
# mean    -4.373606e-17
# std      1.000562e+00
# min     -6.484217e-01
# 25%     -4.891482e-01
# 50%     -3.573909e-01
# 75%     -2.424635e-02
# max      9.667167e+00
# Name: Fare_zscore, dtype: float64

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#                    Age  SibSp  Parch            Ticket     Fare Embarked  \
# PassengerId
# 1            22.000000      1      0         A/5 21171   7.2500        S
# 2            38.000000      1      0          PC 17599  71.2833        C
# 3            26.000000      0      0  STON/O2. 3101282   7.9250        S
# 4            35.000000      1      0            113803  53.1000        S
# 5            35.000000      0      0            373450   8.0500        S
# ...                ...    ...    ...               ...      ...      ...
# 887          27.000000      0      0            211536  13.0000        S
# 888          19.000000      0      0            112053  30.0000        S
# 889          29.699118      1      2        W./C. 6607  23.4500        S
# 890          26.000000      0      0            111369  30.0000        C
# 891          32.000000      0      0            370376   7.7500        Q
#
#               Age-binned  Fare_zscore
# PassengerId
# 1                  Young    -0.502445
# 2            Middle-aged     0.786845
# 3                  Young    -0.488854
# 4            Middle-aged     0.420730
# 5            Middle-aged    -0.486337
# ...                  ...          ...
# 887          Middle-aged    -0.386671
# 888                Young    -0.044381
# 889          Middle-aged    -0.176263
# 890                Young    -0.044381
# 891          Middle-aged    -0.492378
#
# [891 rows x 12 columns]

# %%
# # create a scaler using MinMax normalization on a single attribute
#min_max_scaler = preprocessing.MinMaxScaler().fit(train[['Fare']])

# %%
#Apply the MinMax scaler on a single attribute
#train['Fare_MinMax']=min_max_scaler.transform(train[['Fare']])

# %%
#train['Fare_MinMax'].describe()

# %% [markdown]
# ###### How you can apply the same scaler to test set?

# %% [markdown]
# #### 3. On Hot Encoding

# %%
# get dummy variables for categorical varialbes
sexdummy = pd.get_dummies(train['Sex'])

# %%
sexdummy
# Out:
#              female  male
# PassengerId
# 1                 0     1
# 2                 1     0
# 3                 1     0
# 4                 1     0
# 5                 0     1
# ...             ...   ...
# 887               0     1
# 888               1     0
# 889               1     0
# 890               0     1
# 891               0     1
#
# [891 rows x 2 columns]

# %%
# get dummy variables for "Embarked"
embarkeddummy = pd.get_dummies(train['Embarked'],drop_first=True,prefix='Embarked')

# %%
embarkeddummy
# Out:
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 2                     0           0
# 3                     0           1
# 4                     0           1
# 5                     0           1
# ...                 ...         ...
# 887                   0           1
# 888                   0           1
# 889                   0           1
# 890                   0           0
# 891                   1           0
#
# [891 rows x 2 columns]

# %%
# adding dummy columns to the existing dataframe
trainwithdummy = pd.concat([train,sexdummy,embarkeddummy],axis=1,sort=True)

# %%
trainwithdummy
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#                    Age  SibSp  Parch            Ticket     Fare Embarked  \
# PassengerId
# 1            22.000000      1      0         A/5 21171   7.2500        S
# 2            38.000000      1      0          PC 17599  71.2833        C
# 3            26.000000      0      0  STON/O2. 3101282   7.9250        S
# 4            35.000000      1      0            113803  53.1000        S
# 5            35.000000      0      0            373450   8.0500        S
# ...                ...    ...    ...               ...      ...      ...
# 887          27.000000      0      0            211536  13.0000        S
# 888          19.000000      0      0            112053  30.0000        S
# 889          29.699118      1      2        W./C. 6607  23.4500        S
# 890          26.000000      0      0            111369  30.0000        C
# 891          32.000000      0      0            370376   7.7500        Q
#
#               Age-binned  Fare_zscore  female  male  Embarked_Q  Embarked_S
# PassengerId
# 1                  Young    -0.502445       0     1           0           1
# 2            Middle-aged     0.786845       1     0           0           0
# 3                  Young    -0.488854       1     0           0           1
# 4            Middle-aged     0.420730       1     0           0           1
# 5            Middle-aged    -0.486337       0     1           0           1
# ...                  ...          ...     ...   ...         ...         ...
# 887          Middle-aged    -0.386671       0     1           0           1
# 888                Young    -0.044381       1     0           0           1
# 889          Middle-aged    -0.176263       1     0           0           1
# 890                Young    -0.044381       0     1           0           0
# 891          Middle-aged    -0.492378       0     1           1           0
#
# [891 rows x 16 columns]

# %%
# drop columns that are not needed
traindrop=trainwithdummy.drop(columns=['Name','Sex','Age','Ticket','Fare','male','Embarked'])

# %%
# view the updated dataframe
traindrop.head()
# Out:
#              Survived  Pclass  SibSp  Parch   Age-binned  Fare_zscore  female  \
# PassengerId
# 1                   0       3      1      0        Young    -0.502445       0
# 2                   1       1      1      0  Middle-aged     0.786845       1
# 3                   1       3      0      0        Young    -0.488854       1
# 4                   1       1      1      0  Middle-aged     0.420730       1
# 5                   0       3      0      0  Middle-aged    -0.486337       0
#
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 2                     0           0
# 3                     0           1
# 4                     0           1
# 5                     0           1

# %%
# save the preprocessed data


titanic_train.to_csv(titanic_cleaned.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-83272ec14c8a> in <module>
#       2
#       3
# ----> 4 titanic_train.to_csv(titanic_cleaned.csv)
#
# NameError: name 'titanic_train' is not defined

# %%
traindrop.to.csv(‘titanic_cleaned.csv’)
# Out:
#              Survived  Pclass  SibSp  Parch   Age-binned  Fare_zscore  female  \
# PassengerId
# 1                   0       3      1      0        Young    -0.502445       0
# 2                   1       1      1      0  Middle-aged     0.786845       1
# 3                   1       3      0      0        Young    -0.488854       1
# 4                   1       1      1      0  Middle-aged     0.420730       1
# 5                   0       3      0      0  Middle-aged    -0.486337       0
# ...               ...     ...    ...    ...          ...          ...     ...
# 887                 0       2      0      0  Middle-aged    -0.386671       0
# 888                 1       1      0      0        Young    -0.044381       1
# 889                 0       3      1      2  Middle-aged    -0.176263       1
# 890                 1       1      0      0        Young    -0.044381       0
# 891                 0       3      0      0  Middle-aged    -0.492378       0
#
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 2                     0           0
# 3                     0           1
# 4                     0           1
# 5                     0           1
# ...                 ...         ...
# 887                   0           1
# 888                   0           1
# 889                   0           1
# 890                   0           0
# 891                   1           0
#
# [891 rows x 9 columns]

# %%
traindrop.to_csv('titanic_cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f13ee7263ac8> in <module>
# ----> 1 traindrop.to_csv('titanic_cleaned.csv')
#
# NameError: name 'traindrop' is not defined

# %%
zscore_scaler_test = preprocessing.StandardScaler().fit(test[['Fare']])
